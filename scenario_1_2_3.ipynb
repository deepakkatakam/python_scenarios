# %%
#Processing customer data from a CSV file for a retail company to ensure clean, unique records.

# %%
import pandas as pd
import numpy as np

# %%
customerdata = pd.read_csv(r"C:\Users\Deepak\Downloads\us_customer_data 1.csv")
customerdata1=pd.read_csv(r"C:\Users\Deepak\Downloads\us_customer_data 1.csv")

customerdata
customerdata1
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
customerdata.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                50
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
customerdata['email']=customerdata['email'].fillna(customerdata['name'].str.replace(' ','').str.lower()+"@example.com")

# %%
customerdata.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
customerdata.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
customerdata['phone'] =customerdata['phone'].str.replace(r'[^0-9]','',regex=True)
customerdata['phone']=customerdata['phone'].str.slice(0,10)
customerdata.loc[289]
# Out:
# customer_id                                                 290
# name                                                Tony Barnes
# email                                      daniel85@example.com
# phone                                                3095157385
# address              162 Jeffrey Rapids, Lindsaymouth, OH 43140
# registration_date                                    19-09-2024
# loyalty_status                                             Gold
# Name: 289, dtype: object

# %%
customerdata['phone'] =customerdata['phone'].str.replace(r'[a-zA-Z]','xxx-xxx-xxxx',regex=True)
customerdata.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
customerdata['phone'] =customerdata['phone'].fillna('xxx-xxx-xxxx')
customerdata.loc[customerdata['phone'].str.len()<10,'phone']='xxx-xxx-xxxx'

# %%
customerdata.to_csv('scenario_1.csv',index=False)

# %% [markdown]
# # Standardizing contact details in an Excel file for a marketing campaign using  customer data

# %%
countrycodes = pd.read_csv(r"C:\Users\Deepak\Desktop\python_practice\Country-codes.csv", encoding='ISO-8859-1')

customerdata['country_code'] = customerdata['address'].str.slice(-8, -6)
customerdata['country_code']
customerdata['phone'] = customerdata['phone'].astype(str)
customerdata
customerdata.iloc[289]
# Out:
# customer_id                                                 290
# name                                                Tony Barnes
# email                                      daniel85@example.com
# phone                                                3095157385
# address              162 Jeffrey Rapids, Lindsaymouth, OH 43140
# registration_date                                    19-09-2024
# loyalty_status                                             Gold
# country_code                                                 OH
# Name: 289, dtype: object

# %%
for i in range(len(customerdata)):
    code = customerdata.loc[i, 'country_code']
    found=False
    for j in range(len(countrycodes)):
        if code == countrycodes.loc[j, 'Country_code']:
            dial = countrycodes.loc[j, 'International_dialing']
            customerdata.loc[i, 'phone'] = (str(dial) + " "+ customerdata.loc[i, 'phone'])
            found=True
            break
    if not found:
        customerdata.loc[i, 'phone'] = "+1 " + customerdata.loc[i, 'phone']
customerdata
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#                  phone                                            address  \
# 0      +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
customerdata.to_csv("testing.csv",index=False)

# %% [markdown]
# #3. Filtering high-value transactions from a CSV file for targeted promotions.

# %%
transaction_table=pd.read_csv(r"C:\Users\Deepak\Downloads\transaction_data.csv")
merge_table=pd.merge(customerdata,transaction_table,on="customer_id",how="inner")
merge_table
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 4              7      Louis Miller  patriciaelliott@example.org
# ..           ...               ...                          ...
# 995          995    Deanna Johnson            ycook@example.org
# 996          995    Deanna Johnson            ycook@example.org
# 997          997      Jodi Simpson           eric24@example.org
# 998          998     Crystal Brown         pshaffer@example.net
# 999          998     Crystal Brown         pshaffer@example.net
#
#                  phone                                            address  \
# 0      +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
merge_table.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                 0
# address               0
# registration_date     0
# loyalty_status        0
# country_code          0
# transaction_id        0
# amount               50
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
merge_table['amount']=merge_table['amount'].fillna(merge_table['amount'].mean())
merge_table.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# country_code         0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
spent_more_than_1k=merge_table[merge_table['amount']>1000]
spent_more_than_1k
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 6             10      Rachel White     whitemichael@example.org
# ..           ...               ...                          ...
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org
# 993          995    Deanna Johnson            ycook@example.org
# 994          995    Deanna Johnson            ycook@example.org
# 999          998     Crystal Brown         pshaffer@example.net
#
#                  phone                                            address  \
# 0      +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
spent_more_than_1k.to_csv("result_scenario3.csv",index=False)

# %%
merge_table1=merge_table[merge_table['amount']>merge_table['amount'].mean()]
merge_table1
# Out:
#      customer_id               name                        email  \
# 0              1      Michelle Kidd           vayala@example.net
# 3              7       Louis Miller  patriciaelliott@example.org
# 6             10       Rachel White     whitemichael@example.org
# 7             10       Rachel White     whitemichael@example.org
# 9             12  Christine Delgado         yfarrell@example.net
# ..           ...                ...                          ...
# 990          991      Erica Fleming          erica85@example.net
# 991          991      Erica Fleming          erica85@example.net
# 992          992     Thomas Stevens    vargasmatthew@example.org
# 993          995     Deanna Johnson            ycook@example.org
# 994          995     Deanna Johnson            ycook@example.org
#
#                  phone                                            address  \
# 0      +971 6197234258                        USNS Santiago, FPO AE 80872
# ...
