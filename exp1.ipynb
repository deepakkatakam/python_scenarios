# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Deepak\Downloads\us_customer_data.csv")

# %%
df.tail() #first five rows
# Out:
#      customer_id            name                      email  \
# 995          996  Jerry Mcdaniel     walkerlisa@example.net
# 996          997    Jodi Simpson         eric24@example.org
# 997          998   Crystal Brown       pshaffer@example.net
# 998          999  Gregory Duarte  caitlindunlap@example.org
# 999         1000     Jason Walls      michael42@example.com
#
#                    phone                                            address  \
# 995         838.471.6445           34746 Smith Gateway, New Sarah, AS 12715
# 996  +1-408-681-5204x264  2876 Tucker Road Suite 947, North Tommyborough...
# 997        (962)521-7928  095 Janice Forest Suite 570, Boltonmouth, DE 7...
# 998         750-965-7879                   Unit 6377 Box 7662, DPO AP 03300
# 999  (577)304-8260x99915             95002 Bruce Rue, Camachoport, MH 58723
#
#     registration_date loyalty_status
# 995        2025-02-10         Silver
# 996        2024-04-18         Bronze
# ...

# %%
df.head() #last five rows
# Out:
#    customer_id              name                        email  \
# 0            1     Michelle Kidd           vayala@example.net
# 1            2       Brad Newton  taylorcatherine@example.net
# 2            3      Larry Torres         dsanchez@example.net
# 3            4    Kimberly Price    jessicaknight@example.com
# 4            5  Matthew Phillips        qwilliams@example.com
#
#                     phone                                            address  \
# 0                     NaN                        USNS Santiago, FPO AE 80872
# 1       (759)518-8536x738  38783 Oliver Street, West Kristenborough, MT 9...
# 2  001-323-525-3094x96062     6845 Steele Turnpike, West Erikabury, UT 37487
# 3  001-947-633-4224x07930         1631 Alexis Meadows, Lake Amanda, CA 75179
# 4   001-869-650-5682x8385  2274 Williams Heights Suite 895, Andersonhaven...
#
#   registration_date loyalty_status
# 0        2025-01-25           Gold
# 1        2023-07-13         Silver
# ...

# %%
df.info() #data types and notnull count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              950 non-null    object
#  3   phone              950 non-null    object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
df.columns
# Out:
# Index(['customer_id', 'name', 'email', 'phone', 'address', 'registration_date',
#        'loyalty_status'],
#       dtype='object')

# %%
df.describe()
# Out:
#        customer_id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df1=pd.read_csv(r"C:\Users\Deepak\Downloads\transaction_data.csv")

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df1[df1.duplicated("customer_id")]
# Out:
#      transaction_id  customer_id   amount     transaction_date  \
# 20               21          752  2707.82  2025-05-26 07:35:44
# 45               46          210  4277.78  2025-02-23 04:30:59
# 48               49          752  1431.10  2025-01-19 09:07:55
# 64               65           67  3716.87  2025-04-11 18:34:23
# 90               91          373   457.98  2025-01-11 01:40:24
# ..              ...          ...      ...                  ...
# 993             994          443  4232.53  2025-02-28 04:00:04
# 994             995          927  1368.17  2025-02-08 21:53:32
# 995             996           60   712.47  2025-01-13 14:16:32
# 997             998          669  3069.08  2025-04-01 19:59:01
# 999            1000          925  4141.44  2025-05-24 13:39:19
#
#     product_category payment_method store_location
# 20          Clothing    Credit Card          Miami
# 45            Beauty    Credit Card         Online
# 48       Electronics         PayPal       New York
# ...

# %%
df1.head()
# Out:
#    transaction_id  customer_id   amount     transaction_date product_category  \
# 0               1          565  2992.47  2025-03-10 01:20:54           Sports
# 1               2          323  2041.87  2025-01-02 15:24:19         Clothing
# 2               3          398   107.35  2025-02-16 03:49:01           Beauty
# 3               4           19      NaN  2025-04-30 15:26:23           Sports
# 4               5          547  3063.28  2025-06-14 04:28:53         Clothing
#
#   payment_method store_location
# 0     Debit Card       New York
# 1           Cash       New York
# 2     Debit Card         Online
# 3     Debit Card    Los Angeles
# 4         PayPal    Los Angeles

# %%
spent_more_than_2k = df1[df1['amount']>2000]
spent_more_than_2k
# Out:
#      transaction_id  customer_id   amount     transaction_date  \
# 0                 1          565  2992.47  2025-03-10 01:20:54
# 1                 2          323  2041.87  2025-01-02 15:24:19
# 4                 5          547  3063.28  2025-06-14 04:28:53
# 6                 7          615  3027.38  2025-03-18 15:59:16
# 7                 8            1  2652.57  2025-04-19 14:46:00
# ..              ...          ...      ...                  ...
# 993             994          443  4232.53  2025-02-28 04:00:04
# 996             997          235  2125.18  2025-06-09 12:37:36
# 997             998          669  3069.08  2025-04-01 19:59:01
# 998             999          931  2262.75  2025-06-08 01:36:01
# 999            1000          925  4141.44  2025-05-24 13:39:19
#
#     product_category payment_method store_location
# 0             Sports     Debit Card       New York
# 1           Clothing           Cash       New York
# 4           Clothing         PayPal    Los Angeles
# ...

# %%
df=pd.merge(df,df1,on='customer_id',how='left')
df
# Out:
#       customer_id              name                        email  \
# 0               1     Michelle Kidd           vayala@example.net
# 1               2       Brad Newton  taylorcatherine@example.net
# 2               3      Larry Torres         dsanchez@example.net
# 3               4    Kimberly Price    jessicaknight@example.com
# 4               5  Matthew Phillips        qwilliams@example.com
# ...           ...               ...                          ...
# 1348          997      Jodi Simpson           eric24@example.org
# 1349          998     Crystal Brown         pshaffer@example.net
# 1350          998     Crystal Brown         pshaffer@example.net
# 1351          999    Gregory Duarte    caitlindunlap@example.org
# 1352         1000       Jason Walls        michael42@example.com
#
#                        phone  \
# 0                        NaN
# 1          (759)518-8536x738
# 2     001-323-525-3094x96062
# 3     001-947-633-4224x07930
# 4      001-869-650-5682x8385
# ...

# %%
mail_na = df[df['email'].isna()]
mail_na
# Out:
#       customer_id                        name email                   phone  \
# 43             28                Brandon Hall   NaN            858-252-9573
# 56             36           Christopher Clark   NaN      526.725.4397x47233
# 74             51                 David Garza   NaN   001-823-650-0884x4834
# 104            74                 Tony Romero   NaN                     NaN
# 105            75                 Haley Jones   NaN        282.685.2507x803
# 133            95                 Jacob Pratt   NaN   001-571-489-8010x6124
# 144           104              Jacob Williams   NaN        437-254-2080x480
# 288           210               Steven Little   NaN      (957)520-6709x5149
# 289           210               Steven Little   NaN      (957)520-6709x5149
# 290           210               Steven Little   NaN      (957)520-6709x5149
# 313           226               Ryan Thompson   NaN         +1-669-615-7174
# ...

# %%
df['email'] = df['email'].fillna(
df['name'].str.replace(" ", "").str.lower() + "@gmail.com"
)

# %%
mail_na = df[df['email'].isna()]
mail_na
# Out:
# Empty DataFrame
# Columns: [customer_id, name, email, phone, address, registration_date, loyalty_status, transaction_id, amount, transaction_date, product_category, payment_method, store_location]
# Index: []

# %%
df
# Out:
#       customer_id              name                        email  \
# 0               1     Michelle Kidd           vayala@example.net
# 1               2       Brad Newton  taylorcatherine@example.net
# 2               3      Larry Torres         dsanchez@example.net
# 3               4    Kimberly Price    jessicaknight@example.com
# 4               5  Matthew Phillips        qwilliams@example.com
# ...           ...               ...                          ...
# 1348          997      Jodi Simpson           eric24@example.org
# 1349          998     Crystal Brown         pshaffer@example.net
# 1350          998     Crystal Brown         pshaffer@example.net
# 1351          999    Gregory Duarte    caitlindunlap@example.org
# 1352         1000       Jason Walls        michael42@example.com
#
#                        phone  \
# 0                        NaN
# 1          (759)518-8536x738
# 2     001-323-525-3094x96062
# 3     001-947-633-4224x07930
# 4      001-869-650-5682x8385
# ...

# %%
repeated_customers = df[df.duplicated('customer_id', keep=False)]
repeated_customers
# Out:
#       customer_id            name                        email  \
# 6               7    Louis Miller  patriciaelliott@example.org
# 7               7    Louis Miller  patriciaelliott@example.org
# 10             10    Rachel White     whitemichael@example.org
# 11             10    Rachel White     whitemichael@example.org
# 12             10    Rachel White     whitemichael@example.org
# ...           ...             ...                          ...
# 1344          995  Deanna Johnson            ycook@example.org
# 1345          995  Deanna Johnson            ycook@example.org
# 1346          995  Deanna Johnson            ycook@example.org
# 1349          998   Crystal Brown         pshaffer@example.net
# 1350          998   Crystal Brown         pshaffer@example.net
#
#                      phone                                            address  \
# 6     001-418-931-4146x588        02590 Marshall Well, Sheppardland, CT 88067
# ...

# %%
df
# Out:
#       customer_id              name                        email  \
# 0               1     Michelle Kidd           vayala@example.net
# 1               2       Brad Newton  taylorcatherine@example.net
# 2               3      Larry Torres         dsanchez@example.net
# 3               4    Kimberly Price    jessicaknight@example.com
# 4               5  Matthew Phillips        qwilliams@example.com
# ...           ...               ...                          ...
# 1348          997      Jodi Simpson           eric24@example.org
# 1349          998     Crystal Brown         pshaffer@example.net
# 1350          998     Crystal Brown         pshaffer@example.net
# 1351          999    Gregory Duarte    caitlindunlap@example.org
# 1352         1000       Jason Walls        michael42@example.com
#
#                        phone  \
# 0                        NaN
# 1          (759)518-8536x738
# 2     001-323-525-3094x96062
# 3     001-947-633-4224x07930
# 4      001-869-650-5682x8385
# ...

# %%
df['phone'].isna().sum()
# Out:
# np.int64(70)

# %%
missing_phones = df[df['phone'].isna()]
missing_phones
# Out:
#       customer_id                name                     email phone  \
# 0               1       Michelle Kidd        vayala@example.net   NaN
# 98             68  Christopher Adkins    patricia48@example.com   NaN
# 101            71      Patrick Gibson  ashleygarner@example.org   NaN
# 104            74         Tony Romero      tonyromero@gmail.com   NaN
# 111            81  Charles Fitzgerald      nicole67@example.com   NaN
# ...           ...                 ...                       ...   ...
# 1321          980    Sharon Hernandez      sherry23@example.com   NaN
# 1322          980    Sharon Hernandez      sherry23@example.com   NaN
# 1337          990   Mrs. Alexis Brown         amy77@example.com   NaN
# 1338          991       Erica Fleming       erica85@example.net   NaN
# 1339          991       Erica Fleming       erica85@example.net   NaN
#
#                                                 address registration_date  \
# ...

# %%
df['email']=df['email'].fillna(
    df['name'].str.replace(' ','').str.lower()+""
)

# %%
df
# Out:
#       customer_id              name                        email  \
# 0               1     Michelle Kidd           vayala@example.net
# 1               2       Brad Newton  taylorcatherine@example.net
# 2               3      Larry Torres         dsanchez@example.net
# 3               4    Kimberly Price    jessicaknight@example.com
# 4               5  Matthew Phillips        qwilliams@example.com
# ...           ...               ...                          ...
# 1348          997      Jodi Simpson           eric24@example.org
# 1349          998     Crystal Brown         pshaffer@example.net
# 1350          998     Crystal Brown         pshaffer@example.net
# 1351          999    Gregory Duarte    caitlindunlap@example.org
# 1352         1000       Jason Walls        michael42@example.com
#
#                        phone  \
# 0                        NaN
# 1          (759)518-8536x738
# 2     001-323-525-3094x96062
# 3     001-947-633-4224x07930
# 4      001-869-650-5682x8385
# ...

# %%
df['phone'] = df['phone'].fillna("not provided")

# %%
df
df['phone'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1348    False
# 1349    False
# 1350    False
# 1351    False
# 1352    False
# Name: phone, Length: 1353, dtype: bool

# %%
df.head(60)
# Out:
#     customer_id                   name                        email  \
# 0             1          Michelle Kidd           vayala@example.net
# 1             2            Brad Newton  taylorcatherine@example.net
# 2             3           Larry Torres         dsanchez@example.net
# 3             4         Kimberly Price    jessicaknight@example.com
# 4             5       Matthew Phillips        qwilliams@example.com
# 5             6  Darrell Gallagher DVM      larryharris@example.org
# 6             7           Louis Miller  patriciaelliott@example.org
# 7             7           Louis Miller  patriciaelliott@example.org
# 8             8    Melissa Galloway MD   watsonbenjamin@example.net
# 9             9         Matthew Harvey          bgaines@example.net
# 10           10           Rachel White     whitemichael@example.org
# 11           10           Rachel White     whitemichael@example.org
# 12           10           Rachel White     whitemichael@example.org
# ...

# %%
# Out:
#       customer_id              name                        email  \
# 0               1     Michelle Kidd           vayala@example.net
# 1               2       Brad Newton  taylorcatherine@example.net
# 2               3      Larry Torres         dsanchez@example.net
# 3               4    Kimberly Price    jessicaknight@example.com
# 4               5  Matthew Phillips        qwilliams@example.com
# ...           ...               ...                          ...
# 1348          997      Jodi Simpson           eric24@example.org
# 1349          998     Crystal Brown         pshaffer@example.net
# 1350          998     Crystal Brown         pshaffer@example.net
# 1351          999    Gregory Duarte    caitlindunlap@example.org
# 1352         1000       Jason Walls        michael42@example.com
#
#                        phone  \
# 0               not provided
# 1          (759)518-8536x738
# 2     001-323-525-3094x96062
# 3     001-947-633-4224x07930
# 4      001-869-650-5682x8385
# ...

# %%
merge_table
# Out:
#       customer_id              name                        email  \
# 0               1     Michelle Kidd           vayala@example.net
# 1               2       Brad Newton  taylorcatherine@example.net
# 2               3      Larry Torres         dsanchez@example.net
# 3               4    Kimberly Price    jessicaknight@example.com
# 4               5  Matthew Phillips        qwilliams@example.com
# ...           ...               ...                          ...
# 1348          997      Jodi Simpson           eric24@example.org
# 1349          998     Crystal Brown         pshaffer@example.net
# 1350          998     Crystal Brown         pshaffer@example.net
# 1351          999    Gregory Duarte    caitlindunlap@example.org
# 1352         1000       Jason Walls        michael42@example.com
#
#                        phone  \
# 0               not provided
# 1          (759)518-8536x738
# 2     001-323-525-3094x96062
# 3     001-947-633-4224x07930
# 4      001-869-650-5682x8385
# ...

# %%
df['phone']=df['phone'].fillna('not mentioned')

# %%
df['phone'].isna().sum()
# Out:
#   Cell In[393], line 2
#     merge_table['email']=merge_table['email'].
#                                               ^
# SyntaxError: invalid syntax

# %%
df.to_csv('test1.csv',index=False)

# %%
# Out:
#      transaction_id  customer_id   amount     transaction_date  \
# 20               21          752  2707.82  2025-05-26 07:35:44
# 45               46          210  4277.78  2025-02-23 04:30:59
# 48               49          752  1431.10  2025-01-19 09:07:55
# 64               65           67  3716.87  2025-04-11 18:34:23
# 90               91          373   457.98  2025-01-11 01:40:24
# ..              ...          ...      ...                  ...
# 993             994          443  4232.53  2025-02-28 04:00:04
# 994             995          927  1368.17  2025-02-08 21:53:32
# 995             996           60   712.47  2025-01-13 14:16:32
# 997             998          669  3069.08  2025-04-01 19:59:01
# 999            1000          925  4141.44  2025-05-24 13:39:19
#
#     product_category payment_method store_location
# 20          Clothing    Credit Card          Miami
# 45            Beauty    Credit Card         Online
# 48       Electronics         PayPal       New York
# ...
